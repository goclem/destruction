# %%
import sys
import warnings
warnings.filterwarnings('ignore')

# setting path
sys.path.append('../')
  
from destruction_utilities import prep_all, search_data

cities = ['aleppo', 'damascus', 'daraa', 'deir-ez-zor','hama', 'homs', 'idlib', 'raqqa']
for city in cities:
    prep_all(city, '_test', '../../data')
# Out:
# ../../data/aleppo/others/aleppo_damage.gpkg
# ['../../data/damascus/others/damascus_damage.gpkg', '../../data/damascus/others/damascus_damage.gpkg-shm', '../../data/damascus/others/damascus_damage.gpkg-wal']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 11>()
#      10 cities = ['aleppo', 'damascus', 'daraa', 'deir-ez-zor','hama', 'homs', 'idlib', 'raqqa']
#      11 for city in cities:
# ---> 12     prep_all(city, '_', '../../data')
#
# File ~/projects/mwd/destruction/examples/../destruction_utilities.py:200, in prep_all(city, suffix, datadir)
#     198 def prep_all(city:str, suffix: str, datadir: str) -> None:
#     199     '''One time script to prep damage, noanalysis, and settlement data'''
# --> 200     prep_damage(city, suffix, datadir)
#     201     prep_settlement(city, suffix, datadir)
# ...

# %%
# Out:
# ../../data/aleppo/others/aleppo_damage.gpkg
# /home/andre/projects/mwd/destruction/examples/../destruction_utilities.py:159: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allDates = allDates.append(damage[sensor_date_col])
# /home/andre/projects/mwd/destruction/examples/../destruction_utilities.py:159: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allDates = allDates.append(damage[sensor_date_col])
# /home/andre/miniconda3/envs/destruction/lib/python3.8/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# ...
