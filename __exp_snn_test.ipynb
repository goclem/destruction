# %%
import destruction_models as models
from tensorflow.keras import callbacks, metrics
from tensorflow.keras.utils import Sequence
from destruction_utilities import *
import matplotlib.pyplot as plt
import tensorflow as tf
import time
import pickle

# %%
CITY = 'test'
BATCH_SIZE = 32
TILE_SIZE = [128,128]

# %%
class SiameseGenerator(Sequence):
    def __init__(self, images, labels, batch_size=BATCH_SIZE):
        self.images_t0 = images[0]
        self.images_tt = images[1]
        self.labels = labels
        self.batch_size = batch_size
        self.tuple_pairs = make_tuple_pair(self.images_t0.shape[0], self.batch_size)
        np.random.shuffle(self.tuple_pairs)
   
    def __len__(self):
        return len(self.images_t0)//self.batch_size
    
    def __getitem__(self, index):

        index_range = self.tuple_pairs[index]
        indices = np.arange(0,32)
        np.random.shuffle(indices)
        
        X_t0 = self.images_t0[index_range[0]:index_range[1]][indices]
        X_t1 = self.images_tt[index_range[0]:index_range[1]][indices]
        y = self.labels[index_range[0]:index_range[1]][indices]
        
        return {'images_t0':X_t0, 'images_tt':X_t1}, y

# class SiameseGenerator(Sequence):
#     def __init__(self, images, labels, batch_size=BATCH_SIZE):
#         self.images_t0 = images[0]
#         self.images_tt = images[1]
#         self.labels = labels
#         self.batch_size = batch_size
        
#     def __len__(self):
#         return len(self.images_t0)//self.batch_size
    
#     def __getitem__(self, index):

#         X_t0 = self.images_t0[index*self.batch_size:(index+1)*self.batch_size]
#         X_t1 = self.images_tt[index*self.batch_size:(index+1)*self.batch_size]
#         y = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
#         return {'images_t0':X_t0, 'images_tt':X_t1}, y

# %%
train_images_t0 = read_zarr(CITY, 'images_siamese_train_t0_balanced')
train_images_tt = read_zarr(CITY, 'images_siamese_train_tt_balanced')
train_labels = read_zarr(CITY, 'labels_siamese_train')

valid_images_t0 = read_zarr(CITY, 'images_siamese_valid_t0')
valid_images_tt = read_zarr(CITY, 'images_siamese_valid_tt')
valid_labels = read_zarr(CITY, 'labels_siamese_valid')

train_gen = SiameseGenerator((train_images_t0, train_images_tt), train_labels)
valid_gen = SiameseGenerator((valid_images_t0, valid_images_tt), valid_labels)

# %%
def run_model(train_images, train_labels, valid_images, valid_labels):
    train_gen = SiameseGenerator((train_images[0], train_images[1]), train_labels)
    valid_gen = SiameseGenerator((valid_images[0], valid_images[1]), valid_labels)
    
    training_callbacks = [
        callbacks.EarlyStopping(monitor='val_auc', patience=15, restore_best_weights=True),
        callbacks.ModelCheckpoint(f'../models/{CITY}/snn/', monitor='val_auc', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')

    ]
    
    filters = random.choice([16, 24, 32])
    dropout = random.choice(np.linspace(0.1, 0.2))
    epochs = random.choice(np.arange(70,100))
    units = random.choice([24, 32, 48])
    lr = random.choice([0.003, 0.01, 0.03, 0.1, 0.3])

    args_encode  = dict(filters=filters, dropout=dropout) # ! Check parameters before run
    args_dense  = dict(units=units, dropout=dropout) # ! Check parameters before run

    parameters = f'filters={filters}, \ndropout={np.round(dropout, 4)}, \nepochs={epochs}, \nunits={units}, \nlearning_rate={lr}'
    print(parameters)
    
#     model = models.siamese_convolutional_network(shape=(*TILE_SIZE, 3), args_encode=args_encode, args_dense=args_dense)
    model = models.siamese_convolutional_network(shape=(*TILE_SIZE, 3),  args_encode=dict(filters=8, dropout=0), args_dense=dict(units=16, dropout=0))
   
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy',metrics.AUC(num_thresholds=200, curve='ROC', name='auc')])
    model.summary()
    

    # Train model on dataset
    history = model.fit_generator(
        train_gen,
        validation_data=valid_gen,
        epochs=epochs,
        verbose=1,
        callbacks=training_callbacks
    )
    
    return model, history, parameters

# %%
def plot_training(H, P, ts, plotPath):
	# construct a plot that plots and saves the training history
	plt.style.use("ggplot")
	plt.figure()
	plt.plot(H.history["accuracy"], label="train_accuracy")
	plt.plot(H.history["val_accuracy"], label="val_accuracy")
	plt.plot(H.history["auc"], label="train_auc")
	plt.plot(H.history["val_auc"], label="val_auc")
	plt.title(f"Training Accuracy and AUC")
	plt.suptitle(f"City = {CITY}") 
	plt.xlabel("Epoch #")
	plt.ylabel("AUC")
	plt.text(0.65, 0.18, P + f"\nmax(val_auc)={np.round(np.max(H.history['val_auc']), 4)}\ncode={ts}", fontsize=8, transform=plt.gcf().transFigure)
	plt.legend(loc="lower left")
	plt.savefig(plotPath)

# %%
for i in range(0,5):
    m = run_model((train_images_t0, train_images_tt), train_labels, (valid_images_t0, valid_images_tt), valid_labels)
    model = m[0]
    history = m[1]
    parameters = m[2]
    print("Model optimization complete..\n\n")
    ts = str(np.round(time.time()))
    with open(f'../models/{CITY}_SNN_RUN{i}_{ts}_hist', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
    
    model.save(f'../models/{CITY}_SNN_RUN{i}_{ts}', save_format="h5")
    plot_training(history, parameters, ts, f'../figures/{CITY}_SNN_RUN{i}_{ts}.png')
    
    with open('../models/run_parameters.txt', "a") as file:
        file.write(f'{CITY}_SNN_RUN{i}_{ts}: \n \t{parameters}\n')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# filters=16,
# dropout=0.2,
# epochs=82,
# units=24,
# learning_rate=0.003
# Metal device set to: Apple M1
# Model: "siamese_convolutional_network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  images_t0 (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  images_tt (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  encoder (Functional)           (None, 640)          23736       ['images_t0[0][0]',
#                                                                   'images_tt[0][0]']
#
#  concatenate (Concatenate)      (None, 1280)         0           ['encoder[0][0]',
#                                                                   'encoder[1][0]']
#
#  dense_block1_dense (Dense)     (None, 16)           20480       ['concatenate[0][0]']
#
#  dense_block1_normalisation (Ba  (None, 16)          64          ['dense_block1_dense[0][0]']
#  tchNormalization)
#
#  dense_block1_dropout (Dropout)  (None, 16)          0           ['dense_block1_normalisation[0][0
#                                                                  ]']
#
#  dense_block2_dense (Dense)     (None, 16)           256         ['dense_block1_dropout[0][0]']
#
#  dense_block2_normalisation (Ba  (None, 16)          64          ['dense_block2_dense[0][0]']
#  tchNormalization)
#
#  dense_block2_dropout (Dropout)  (None, 16)          0           ['dense_block2_normalisation[0][0
#                                                                  ]']
#
#  dense_block3_dense (Dense)     (None, 16)           256         ['dense_block2_dropout[0][0]']
#
#  dense_block3_normalisation (Ba  (None, 16)          64          ['dense_block3_dense[0][0]']
#  tchNormalization)
#
#  dense_block3_dropout (Dropout)  (None, 16)          0           ['dense_block3_normalisation[0][0
#                                                                  ]']
#
#  outputs (Dense)                (None, 1)            17          ['dense_block3_dropout[0][0]']
#
# ==================================================================================================
# Total params: 44,937
# Trainable params: 44,601
# Non-trainable params: 336
# __________________________________________________________________________________________________
# 2022-07-13 17:15:22.684769: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-13 17:15:22.684894: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /var/folders/z1/7pydgng971nfzdf2rwg_p__r0000gn/T/ipykernel_24709/690366530.py:32: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 2022-07-13 17:15:22.886508: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/82
# 2022-07-13 17:15:23.614546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 27/27 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.6100 - auc: 0.6440
# 2022-07-13 17:15:25.660309: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-07-13 17:15:26.646973: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ../models/test/snn/assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       1 for i in range(0,5):
# ----> 2     m = run_model((train_images_t0, train_images_tt), train_labels, (valid_images_t0, valid_images_tt), valid_labels)
#       3     model = m[0]
#       4     history = m[1]
#
# Input In [5], in run_model(train_images, train_labels, valid_images, valid_labels)
#      28 model.summary()
#      31 # Train model on dataset
# ---> 32 history = model.fit_generator(
#      33     train_gen,
#      34     validation_data=valid_gen,
#      35     epochs=epochs,
#      36     verbose=1,
#      37     callbacks=training_callbacks
#      38 )
#      40 return model, history, parameters
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/engine/training.py:2209, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2198 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2199
#    2200 DEPRECATED:
#    2201   `Model.fit` now supports generators, so there is no longer any need to use
#    2202   this endpoint.
#    2203 """
#    2204 warnings.warn(
#    2205     '`Model.fit_generator` is deprecated and '
#    2206     'will be removed in a future version. '
#    2207     'Please use `Model.fit`, which supports generators.',
#    2208     stacklevel=2)
# -> 2209 return self.fit(
#    2210     generator,
#    2211     steps_per_epoch=steps_per_epoch,
#    2212     epochs=epochs,
#    2213     verbose=verbose,
#    2214     callbacks=callbacks,
#    2215     validation_data=validation_data,
#    2216     validation_steps=validation_steps,
#    2217     validation_freq=validation_freq,
#    2218     class_weight=class_weight,
#    2219     max_queue_size=max_queue_size,
#    2220     workers=workers,
#    2221     use_multiprocessing=use_multiprocessing,
#    2222     shuffle=shuffle,
#    2223     initial_epoch=initial_epoch)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/engine/training.py:1435, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1432   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433   epoch_logs.update(val_logs)
# -> 1435 callbacks.on_epoch_end(epoch, epoch_logs)
#    1436 training_logs = epoch_logs
#    1437 if self.stop_training:
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     414 logs = self._process_logs(logs)
#     415 for callback in self.callbacks:
# --> 416   callback.on_epoch_end(epoch, logs)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/callbacks.py:1388, in ModelCheckpoint.on_epoch_end(self, epoch, logs)
#    1386 # pylint: disable=protected-access
#    1387 if self.save_freq == 'epoch':
# -> 1388   self._save_model(epoch=epoch, batch=None, logs=logs)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/callbacks.py:1443, in ModelCheckpoint._save_model(self, epoch, batch, logs)
#    1440     self.model.save_weights(
#    1441         filepath, overwrite=True, options=self._options)
#    1442   else:
# -> 1443     self.model.save(filepath, overwrite=True, options=self._options)
#    1444 else:
#    1445   if self.verbose > 0:
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/engine/training.py:2384, in Model.save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2342 """Saves the model to Tensorflow SavedModel or a single HDF5 file.
#    2343
#    2344 Please see `tf.keras.models.save_model` or the
#    (...)
#    2381 ```
#    2382 """
#    2383 # pylint: enable=line-too-long
# -> 2384 save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2385                 signatures, options, save_traces)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/saving/save.py:151, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     149 else:
#     150   with generic_utils.SharedObjectSavingScope():
# --> 151     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#     152                           signatures, options, save_traces)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/keras/saving/saved_model/save.py:93, in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      91 with backend.deprecated_internal_learning_phase_scope(0):
#      92   with utils.keras_option_scope(save_traces):
# ---> 93     saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      94         model, filepath, signatures, options)
#      96   # Save all metadata to a separate file in the SavedModel directory.
#      97   metadata = generate_keras_metadata(saved_nodes, node_paths)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/tensorflow/python/saved_model/save.py:1404, in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1398 pywrap_saved_model.Save(export_dir)
#    1400 path = file_io.join(
#    1401     compat.as_str(export_dir),
#    1402     compat.as_str(constants.SAVED_MODEL_FILENAME_PB))
#    1403 file_io.atomic_write_string_to_file(
# -> 1404     path, saved_model.SerializeToString(deterministic=True))
#    1405 # Save debug info, if requested.
#    1406 if options.save_debug_info:
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1086, in _AddSerializeToStringMethod.<locals>.SerializeToString(self, **kwargs)
#    1082 if not self.IsInitialized():
#    1083   raise message_mod.EncodeError(
#    1084       'Message %s is missing required fields: %s' % (
#    1085       self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1086 return self.SerializePartialToString(**kwargs)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1095, in _AddSerializePartialToStringMethod.<locals>.SerializePartialToString(self, **kwargs)
#    1093 def SerializePartialToString(self, **kwargs):
#    1094   out = BytesIO()
# -> 1095   self._InternalSerialize(out.write, **kwargs)
#    1096   return out.getvalue()
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
#     [... skipping similar frames: _AddSerializePartialToStringMethod.<locals>.InternalSerialize at line 1115 (1 times)]
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
#     [... skipping similar frames: _AddSerializePartialToStringMethod.<locals>.InternalSerialize at line 1115 (1 times)]
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:827, in MapEncoder.<locals>.EncodeField(write, value, deterministic)
#     825 for key in value_keys:
#     826   entry_msg = message_type._concrete_class(key=key, value=value[key])
# --> 827   encode_message(write, entry_msg, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1111, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 if descriptor.GetOptions().map_entry:
#    1108   # Fields of map entry should always be serialized.
#    1109   descriptor.fields_by_name['key']._encoder(
#    1110       write_bytes, self.key, deterministic)
# -> 1111   descriptor.fields_by_name['value']._encoder(
#    1112       write_bytes, self.value, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:827, in MapEncoder.<locals>.EncodeField(write, value, deterministic)
#     825 for key in value_keys:
#     826   entry_msg = message_type._concrete_class(key=key, value=value[key])
# --> 827   encode_message(write, entry_msg, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1111, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 if descriptor.GetOptions().map_entry:
#    1108   # Fields of map entry should always be serialized.
#    1109   descriptor.fields_by_name['key']._encoder(
#    1110       write_bytes, self.key, deterministic)
# -> 1111   descriptor.fields_by_name['value']._encoder(
#    1112       write_bytes, self.value, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
#     [... skipping similar frames: _AddSerializePartialToStringMethod.<locals>.InternalSerialize at line 1115 (1 times)]
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:465, in _SimpleEncoder.<locals>.SpecificEncoder.<locals>.EncodeField(write, value, deterministic)
#     463 def EncodeField(write, value, deterministic):
#     464   write(tag_bytes)
# --> 465   return encode_value(write, value, deterministic)
#
# File ~/miniforge3/envs/destruction/lib/python3.8/site-packages/google/protobuf/internal/encoder.py:399, in _SignedVarintEncoder.<locals>.EncodeSignedVarint(write, value, unused_deterministic)
#     397 value >>= 7
#     398 while value:
# --> 399   write(local_int2byte(0x80|bits))
#     400   bits = value & 0x7f
#     401   value >>= 7
#
# KeyboardInterrupt:

# %% [markdown]
# ```
# filters=32, dropout=0.13163265306122449, epochs=77, units=32, learning_rate=0.01
# filters=32, dropout=0.18571428571428572, epochs=88, units=48, learning_rate=0.003
#
# Upto 88
# filters=32,
# dropout=0.1939,
# epochs=77,
# units=32,
# learning_rate=0.012
#
#
# ```
