# %%
import destruction_models as models
from tensorflow.keras import callbacks, metrics
from tensorflow.keras.utils import Sequence
from destruction_utilities import *

# %%
CITY = 'aleppo'
BATCH_SIZE = 32

# %%
class SiameseGenerator(Sequence):
    def __init__(self, images, labels, batch_size=BATCH_SIZE):
        self.images_t0 = images[0]
        self.images_tt = images[1]
        self.labels = labels
        self.batch_size = batch_size
        
    def __len__(self):
        return len(self.images_t0)//self.batch_size
    
    def __getitem__(self, index):

        X_t0 = self.images_t0[index*self.batch_size:(index+1)*self.batch_size]
        X_t1 = self.images_tt[index*self.batch_size:(index+1)*self.batch_size]
        y = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        return {'images_t0':X_t0, 'images_tt':X_t1}, y

# %%
train_images_t0 = read_zarr(CITY, 'images_siamese_train_t0')
train_images_tt = read_zarr(CITY, 'images_siamese_train_tt')
train_labels = read_zarr(CITY, 'labels_siamese_train')

valid_images_t0 = read_zarr(CITY, 'images_siamese_valid_t0')
valid_images_tt = read_zarr(CITY, 'images_siamese_valid_tt')
valid_labels = read_zarr(CITY, 'labels_siamese_valid')

train_gen = SiameseGenerator((train_images_t0, train_images_tt), train_labels)
valid_gen = SiameseGenerator((valid_images_t0, valid_images_tt), valid_labels)

# %%
model = models.siamese_convolutional_network(shape=(128, 128, 3), args_encode=dict(filters=8, dropout=0), args_dense=dict(units=16, dropout=0))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',metrics.AUC(num_thresholds=200, curve='ROC')])
model.summary()
# Out:
# Metal device set to: Apple M1
# 2022-07-09 02:35:18.654208: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-09 02:35:18.654334: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "siamese_convolutional_network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  images_t0 (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  images_tt (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  encoder (Functional)           (None, 640)          23736       ['images_t0[0][0]',
#                                                                   'images_tt[0][0]']
#
#  concatenate (Concatenate)      (None, 1280)         0           ['encoder[0][0]',
#                                                                   'encoder[1][0]']
#
#  dense_block1_dense (Dense)     (None, 16)           20480       ['concatenate[0][0]']
#
#  dense_block1_normalisation (Ba  (None, 16)          64          ['dense_block1_dense[0][0]']
#  tchNormalization)
#
#  dense_block1_dropout (Dropout)  (None, 16)          0           ['dense_block1_normalisation[0][0
#                                                                  ]']
#
#  dense_block2_dense (Dense)     (None, 16)           256         ['dense_block1_dropout[0][0]']
#
#  dense_block2_normalisation (Ba  (None, 16)          64          ['dense_block2_dense[0][0]']
#  tchNormalization)
#
#  dense_block2_dropout (Dropout)  (None, 16)          0           ['dense_block2_normalisation[0][0
#                                                                  ]']
#
#  dense_block3_dense (Dense)     (None, 16)           256         ['dense_block2_dropout[0][0]']
#
#  dense_block3_normalisation (Ba  (None, 16)          64          ['dense_block3_dense[0][0]']
#  tchNormalization)
#
#  dense_block3_dropout (Dropout)  (None, 16)          0           ['dense_block3_normalisation[0][0
#                                                                  ]']
#
#  outputs (Dense)                (None, 1)            17          ['dense_block3_dropout[0][0]']
#
# ==================================================================================================
# Total params: 44,937
# Trainable params: 44,601
# Non-trainable params: 336
# __________________________________________________________________________________________________

# %%
training = model.fit_generator(train_gen,
    validation_data=valid_gen,
    epochs=10,
    verbose=1,
    callbacks=callbacks.EarlyStopping(monitor='val_auc', patience=5, restore_best_weights=True)
)
# Out:
# Epoch 1/10
# /var/folders/z1/7pydgng971nfzdf2rwg_p__r0000gn/T/ipykernel_26285/4117531137.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   training = model.fit_generator(train_gen,
# 2022-07-09 02:35:50.020415: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-09 02:35:50.909639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#  470/1380 [=========>....................] - ETA: 2:52 - loss: -0.9739 - accuracy: 0.4244 - auc: 0.5857
